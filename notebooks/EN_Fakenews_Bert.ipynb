# %% [markdown]
# 1- Configuration de l'Environnement

# %%
#!pip install -U transformers datasets accelerate scikit-learn nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\lamya\appdata\roaming\python\python314\site-packages (4.57.3)
# Requirement already satisfied: datasets in c:\users\lamya\appdata\roaming\python\python314\site-packages (4.4.2)
# Collecting accelerate
#   Using cached accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn in c:\users\lamya\appdata\roaming\python\python314\site-packages (1.8.0)
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: filelock in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (3.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Using cached pyarrow-22.0.0-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\lamya\appdata\roaming\python\python314\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in c:\users\lamya\appdata\roaming\python\python314\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in c:\users\lamya\appdata\roaming\python\python314\site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in c:\users\lamya\appdata\roaming\python\python314\site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\lamya\appdata\roaming\python\python314\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\lamya\appdata\roaming\python\python314\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Collecting psutil (from accelerate)
#   Downloading psutil-7.2.1-cp37-abi3-win_amd64.whl.metadata (23 kB)
# Collecting torch>=2.0.0 (from accelerate)
#   Using cached torch-2.9.1-cp314-cp314-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from scikit-learn) (3.6.0)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\lamya\appdata\roaming\python\python314\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lamya\appdata\roaming\python\python314\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\lamya\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached accelerate-1.12.0-py3-none-any.whl (380 kB)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached pyarrow-22.0.0-cp314-cp314-win_amd64.whl (28.8 MB)
# Using cached torch-2.9.1-cp314-cp314-win_amd64.whl (110.9 MB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading psutil-7.2.1-cp37-abi3-win_amd64.whl (136 kB)
# Installing collected packages: pyarrow, psutil, click, torch, nltk, accelerate
#
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ---------------------------------------- 0/6 [pyarrow]
#    ------ --------------------------------- 1/6 [psutil]
#    ------ --------------------------------- 1/6 [psutil]
#    ------------- -------------------------- 2/6 [click]
#    ------------- -------------------------- 2/6 [click]
#    ------------- -------------------------- 2/6 [click]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------- ------------------- 3/6 [torch]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    --------------------------------- ------ 5/6 [accelerate]
#    ---------------------------------------- 6/6 [accelerate]
#
# Successfully installed accelerate-1.12.0 click-8.3.1 nltk-3.9.2 psutil-7.2.1 pyarrow-22.0.0 torch-2.9.1
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\lamya\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'C:\Users\lamya\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts accelerate-config.exe, accelerate-estimate-memory.exe, accelerate-launch.exe, accelerate-merge-weights.exe and accelerate.exe are installed in 'C:\Users\lamya\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Configuration du Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Project running on: {device} | GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# Project running on: cuda | GPU: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# 2. Chargement et Exploration du Dataset

# %%
# Chargement du dataset
raw_datasets = load_dataset("GonzaloA/fake_news")

# Conversion rapide en Pandas pour l'analyse visuelle
df_train = pd.DataFrame(raw_datasets['train'])

# Visualisation de l'équilibre des classes
plt.figure(figsize=(8, 5))
sns.countplot(x='label', data=df_train)
plt.title('Distribution des Fake News (1) vs Reliable (0)')
plt.show()

# Analyse de la longueur des textes (crucial pour BERT)
df_train['text_len'] = df_train['text'].apply(lambda x: len(x.split()))
print(f"Longueur moyenne: {df_train['text_len'].mean():.2f} mots")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Longueur moyenne: 406.45 mots

# %% [markdown]
# 3. Prétraitement et Nettoyage Avancé (Pipeline NLP)

# %%
import os
import re
import pandas as pd
from datasets import load_dataset

# Configuration du dossier
os.makedirs('data', exist_ok=True)

def deep_clean_logic(text):
    if not isinstance(text, str): return ""
    # Nettoyage spécifique Fake News
    text = re.sub(r'https?://\S+|www\.\S+', '[URL]', text) # Garder la trace des liens
    text = re.sub(r'\s+', ' ', text).strip()               # Nettoyer les espaces
    return text

# Chargement
raw_datasets = load_dataset("GonzaloA/fake_news")

for split in ['train', 'validation', 'test']:
    # Conversion en DataFrame
    df = pd.DataFrame(raw_datasets[split])
    
    # 1. Suppression de la colonne d'index inutile
    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])
    
    # 2. Nettoyage avancé du Titre et du Texte
    df['title'] = df['title'].apply(deep_clean_logic)
    df['text'] = df['text'].apply(deep_clean_logic)
    
    # 3. Sauvegarde en respectant les labels initiaux
    file_path = f"data/{split}_cleaned.csv"
    df.to_csv(file_path, index=False, encoding='utf-8')
    print(f"Fichier {split} généré : {df.columns.tolist()} | {len(df)} lignes")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Fichier train généré : ['title', 'text', 'label'] | 24353 lignes
# Fichier validation généré : ['title', 'text', 'label'] | 8117 lignes
# Fichier test généré : ['title', 'text', 'label'] | 8117 lignes

# %%
# Affichage pour inspection Data Science
for split in ['train', 'validation', 'test']:

    df_sample = pd.read_csv(f"data/{split}_cleaned.csv", nrows=3)
    print(f"\n--- Top 3 {split.upper()} ---")
    display(df_sample)
# Out:
# --- Top 3 TRAIN ---
#                                                title  \
# 0  ‘Maury’ Show Official Facebook Posts F*CKED UP...
# 1  Trump’s Favorite News Channel Tries To Soothe ...
# 2  Russia warns Iraq, Kurds not to destabilize Mi...
#
#                                                 text  label
# 0  Maury is perhaps one of the trashiest shows on...      0
# 1  Yesterday, after the father of one of the UCLA...      0
# 2  MOSCOW (Reuters) - Russia on Wednesday warned ...      1
# --- Top 3 VALIDATION ---
#                                                title  \
# 0  Trump says to spend extra day in Philippines d...
# 1       Fire in Bangladesh textile factory kills six
# 2  Myanmar army drops charges against six journal...
#
#                                                 text  label
# 0  WASHINGTON (Reuters) - President Donald Trump ...      1
# 1  DHAKA (Reuters) - A fire in a textile factory ...      1
# 2  YANGON (Reuters) - Myanmar s military on Frida...      1
# --- Top 3 TEST ---
#                                                title  \
# 0  FORMER U.S. ATTORNEY: “It’s VERY Clear Intel C...
# 1  Rick Santorum Advises President To Quit Tweeti...
# 2  Stephen Colbert Explains The Horrifying Future...
#
#                                                 text  label
# 0  JOE DIGENOVA has been around D.C for decades a...      0
# 1  In a recent interview with CNN, former senator...      0
# 2  With only three clowns left in GOP clown car, ...      0

# %% [markdown]
# 4. Analyse de la Distribution des Classes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration du style visuel
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
fig.suptitle('Distribution des Classes (True vs Fake) par Dataset', fontsize=16)

for i, (name, path) in enumerate(files.items()):
    df = pd.read_csv(path)
    
    # Création de l'histogramme
    sns.countplot(x='label', data=df, ax=axes[i], palette='viridis')
    
    # Personnalisation
    axes[i].set_title(f"Split: {name}")
    axes[i].set_xlabel("Label (0: True, 1: Fake)")
    axes[i].set_ylabel("Nombre d'articles" if i == 0 else "")
    
    # Ajout des étiquettes de texte sur les barres
    for p in axes[i].patches:
        axes[i].annotate(f'{int(p.get_height())}', 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha = 'center', va = 'center', 
                         xytext = (0, 9), 
                         textcoords = 'offset points')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# C:\Users\lamya\AppData\Local\Temp\ipykernel_9060\1917325382.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, ax=axes[i], palette='viridis')
# C:\Users\lamya\AppData\Local\Temp\ipykernel_9060\1917325382.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, ax=axes[i], palette='viridis')
# C:\Users\lamya\AppData\Local\Temp\ipykernel_9060\1917325382.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, ax=axes[i], palette='viridis')

# %% [markdown]
# 5. Tokenisation Stratégique (BERT Tokenizer)

# %%
from transformers import AutoTokenizer

# Utilisation du modèle de base BERT
MODEL_NAME = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def preprocess_function(examples):
    # On combine Titre et Texte avec le séparateur spécial [SEP]
    # Cela permet à BERT de comprendre la relation entre les deux
    inputs = [f"{t} [SEP] {txt}" for t, txt in zip(examples["title"], examples["text"])]
    
    return tokenizer(
        inputs,
        padding="max_length",
        truncation=True,
        max_length=512, # Optimisé pour votre GPU
        return_tensors="pt"
    )

# Conversion du dataset nettoyé vers le format Tokenisé
from datasets import load_from_disk, DatasetDict, Dataset

# Re-charger les CSV proprement dans un objet DatasetDict
train_df = pd.read_csv("data/train_cleaned.csv")
val_df = pd.read_csv("data/validation_cleaned.csv")
test_df = pd.read_csv("data/test_cleaned.csv")

dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(train_df),
    "validation": Dataset.from_pandas(val_df),
    "test": Dataset.from_pandas(test_df)
})

# Application de la tokenisation (batched=True utilise le multi-threading)
tokenized_datasets = dataset_dict.map(preprocess_function, batched=True)

# Nettoyage des colonnes texte pour le modèle
tokenized_datasets = tokenized_datasets.remove_columns(["title", "text"])
if 'Unnamed: 0' in tokenized_datasets['train'].column_names:
    tokenized_datasets = tokenized_datasets.remove_columns(["Unnamed: 0"])

tokenized_datasets.set_format("torch")
# Out:
# Map:   0%|          | 0/24353 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8117 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8117 [00:00<?, ? examples/s]

# %% [markdown]
# Vérification du format GPU

# %%
# Affichage d'un exemple tokenisé
sample = tokenized_datasets["train"][0]
print(f"Forme des Input IDs : {sample['input_ids'].shape}")
print(f"Forme de l'Attention Mask : {sample['attention_mask'].shape}")
print(f"Label : {sample['label']}")
# Out:
# Forme des Input IDs : torch.Size([512])
# Forme de l'Attention Mask : torch.Size([512])
# Label : 0

# %% [markdown]
# 6. Configuration du Fine-Tuning (Modèle & Hyperparamètres)

# %%
from transformers import BertForSequenceClassification, TrainingArguments, Trainer
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# 1. Charger l'architecture BERT avec une tête de classification (2 classes)
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)

# 2. Fonction pour calculer les performances (indispensable en Data Science)
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    
    acc = accuracy_score(labels, predictions)
    f1 = f1_score(labels, predictions, average='weighted')
    
    return {
        "accuracy": acc,
        "f1": f1
    }
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./results_fakenews_bert_eng0301",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=100,
    eval_strategy="epoch",      # Changement ici : 'evaluation_strategy' -> 'eval_strategy'
    save_strategy="epoch",
    load_best_model_at_end=True,
    fp16=True,                   # Toujours actif pour votre 3050 Ti
    report_to="none"             # Optionnel : évite de demander des comptes WandB/Comet
)

# %% [markdown]
# 7. Entraînement du Modèle (Fine-Tuning)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    compute_metrics=compute_metrics,
)

# C'est ici que votre GPU va commencer à travailler intensément !
trainer.train()
# Out:
#     <div>
#
#       <progress value='9135' max='9135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9135/9135 54:25, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.070700</td>
#       <td>0.086549</td>
#       <td>0.980042</td>
#       <td>0.980046</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.019100</td>
#       <td>0.066332</td>
#       <td>0.986818</td>
#       <td>0.986814</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.027700</td>
#       <td>0.043860</td>
#       <td>0.989405</td>
#       <td>0.989405</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9135, training_loss=0.05232148650701279, metrics={'train_runtime': 3266.2209, 'train_samples_per_second': 22.368, 'train_steps_per_second': 2.797, 'total_flos': 1.922263059354624e+16, 'train_loss': 0.05232148650701279, 'epoch': 3.0})

# %% [markdown]
# 8. Évaluation et Analyse des Performances

# %%
# Évaluation sur le dataset de test
test_results = trainer.evaluate(tokenized_datasets["test"])

print("--- RÉSULTATS FINAUX SUR LE TEST SET ---")
for key, value in test_results.items():
    print(f"{key}: {value:.4f}")
# Out:
# --- RÉSULTATS FINAUX SUR LE TEST SET ---
# eval_loss: 0.0461
# eval_accuracy: 0.9894
# eval_f1: 0.9894
# eval_runtime: 78.4885
# eval_samples_per_second: 103.4160
# eval_steps_per_second: 12.9320
# epoch: 3.0000

# %% [markdown]
# Matrice de Confusion & Analyse d'Erreurs

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Récupérer les prédictions sur le test set
outputs = trainer.predict(tokenized_datasets["test"])
y_preds = np.argmax(outputs.predictions, axis=-1)
y_true = outputs.label_ids

# Créer et afficher la matrice de confusion
cm = confusion_matrix(y_true, y_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["True", "Fake"])
disp.plot(cmap="Blues")
plt.title("Matrice de Confusion : Détection de Fake News")
plt.show()

# %% [markdown]
# Sauvegarde du Modèle

# %%
# Sauvegarde locale du modèle et du tokenizer
model_path = "./ENG_Bert_fake_news_model_0301"
trainer.save_model(model_path)
tokenizer.save_pretrained(model_path)
print(f"Modèle sauvegardé dans : {model_path}")
# Out:
# Modèle sauvegardé dans : ./ENG_Bert_fake_news_model_0301

# %% [markdown]
# 9. Inférence et Tests en Conditions Réelles

# %%
def predict_news(title, text):
    input_text = f"{title} [SEP] {text}"
    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=512).to("cuda")
    
    model.eval()
    with torch.no_grad():
        logits = model(**inputs).logits
        prediction = torch.argmax(logits, dim=-1).item()
        probability = torch.nn.functional.softmax(logits, dim=-1)

    # Logique alignée sur le dataset (0: Fake, 1: True)
    label = "FAKE 🚩" if prediction == 0 else "TRUE ✅"
    
    print(f"\n--- TEST BERT ---")
    print(f"Résultat : {label}")
    print(f"Confiance : {probability[0][prediction].item()*100:.2f}%")


# Test sur le domaine d'origine (Politique)
title_pol = "White House announces new diplomatic strategy for Middle East"
text_pol = "The administration officials met with regional leaders today to discuss a long-term peace plan and economic cooperation agreements."

predict_news(title_pol, text_pol)
# Out:
# --- TEST BERT ---
# Résultat : TRUE ✅
# Confiance : 94.22%

# %% [markdown]
# remarke :
# l'entraînement est réussi : Le modèle est capable d'identifier les mécanismes de désinformation.
#
# Le modèle est sensible au style : L'exemple des "citrons" utilisait un ton très agressif et sensationnaliste que BERT a reconnu comme étant suspect, contrairement à l'exemple des "aliens" qui imitait un rapport officiel trop sérieusement.

# %%
from sklearn.metrics import classification_report

# Générer le rapport détaillé
report = classification_report(y_true, y_preds, target_names=["True", "Fake"])
print("--- RAPPORT DE CLASSIFICATION DÉTAILLÉ ---")
print(report)
# Out:
# --- RAPPORT DE CLASSIFICATION DÉTAILLÉ ---
#               precision    recall  f1-score   support
#
#         True       0.99      0.99      0.99      3782
#         Fake       0.99      0.99      0.99      4335
#
#     accuracy                           0.99      8117
#    macro avg       0.99      0.99      0.99      8117
# weighted avg       0.99      0.99      0.99      8117

# %%
from huggingface_hub import notebook_login

# 1. Connexion (il va t'ouvrir une fenêtre pour coller ton Token)
notebook_login()

# 2. Définition du nom de ton dépôt
repo_name = "LamT45/ENG_Bert_fake_news_model_0301" 

# 3. Envoi du modèle et du tokenizer
model.push_to_hub(repo_name)
tokenizer.push_to_hub(repo_name)

print(f"Modèle publié ici : https://huggingface.co/{repo_name}")
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md: 0.00B [00:00, ?B/s]
# c:\Users\lamya\anaconda3\envs\torch_env\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\lamya\.cache\huggingface\hub\models--LamT45--ENG_Bert_fake_news_model_0301. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Modèle publié ici : https://huggingface.co/LamT45/ENG_Bert_fake_news_model_0301
